# %%
print('olá mundo!')


#variáveis
numero = 3
print(numero)


#soma
soma = 1+3
print(soma)
# Out:
# olá mundo!
# 3
# 4

# %%
texto = "A música é uma das formas mais antigas e poderosas de expressão humana." \
" Presente em praticamente todas as culturas e civilizações ao longo da história, ela transcende barreiras linguísticas, " \
"sociais e culturais. Uma melodia pode emocionar, inspirar, confortar ou até provocar transformações " \
"internas profundas — tudo sem dizer uma única palavra"
print(texto)

#replace
texto.replace('t','T')
# Out:
# A música é uma das formas mais antigas e poderosas de expressão humana. Presente em praticamente todas as culturas e civilizações ao longo da história, ela transcende barreiras linguísticas, sociais e culturais. Uma melodia pode emocionar, inspirar, confortar ou até provocar transformações internas profundas — tudo sem dizer uma única palavra
# 'A música é uma das formas mais anTigas e poderosas de expressão humana. PresenTe em praTicamenTe Todas as culTuras e civilizações ao longo da hisTória, ela Transcende barreiras linguísTicas, sociais e culTurais. Uma melodia pode emocionar, inspirar, conforTar ou aTé provocar Transformações inTernas profundas — Tudo sem dizer uma única palavra'

# %%
#texto
texto = "A música é uma das formas mais antigas e poderosas de expressão humana." \
" Presente em praticamente todas as culturas e civilizações ao longo da história, ela transcende barreiras linguísticas, " \
"sociais e culturais. Uma melodia pode emocionar, inspirar, confortar ou até provocar transformações " \
"internas profundas — tudo sem dizer uma única palavra"
print(texto)
# Out:
# A música é uma das formas mais antigas e poderosas de expressão humana. Presente em praticamente todas as culturas e civilizações ao longo da história, ela transcende barreiras linguísticas, sociais e culturais. Uma melodia pode emocionar, inspirar, confortar ou até provocar transformações internas profundas — tudo sem dizer uma única palavra

# %%
#multiplicação
inteiro1= 5
inteiro2= 16

multi = inteiro1*inteiro2
print(multi)
# Out:
# 80

# %%
texto2 = "A música"
texto2=texto2 [0:5]
print(texto2)
# Out:
# A mús

# %%
float = 3.5
float
# Out:
# 3.5

# %%
#booleano
print(3==5)
verdadeiro = True
falso = False

print(verdadeiro+falso)
print(verdadeiro * 2)
print(falso * 2)
# Out:
# False
# 1
# 2
# 0

# %%
#list
lista=[1,2,3,4, "teste",3.5]

# %%
#dicionário
dic= {'um':1, 'dois':2,'tres':3}
print(type(lista))
print(type(dic))
print(type(verdadeiro))
# Out:
# <class 'list'>
# <class 'dict'>
# <class 'bool'>

# %%
#subtração
3-5
# Out:
# -2

# %%
#multi
3*5
# Out:
# 15

# %%
#divisão
16/2
# Out:
# 8.0

# %%
texto1= "café"
texto2= "quente"
print(texto1+'  ' +texto2)
print(texto1*20)
print(texto1+'.....'+texto2+' '+ ":D")
# Out:
# café  quente
# cafécafécafécafécafécafécafécafécafécafécafécafécafécafécafécafécafécafécafécafé
# café.....quente :D

# %%
texto1= "café"
texto2= "quente"
print(texto1+'  ' +texto2)
print(texto1*20)
print(texto1+'.....'+texto2+' '+ ":D")

# %%
produto= "café"
preco = "20.00"
Quantidade = "1"
print(produto+'.....'+ 'R$'+ preco+'.....'+ Quantidade)
# Out:
# café.....R$20.00.....1

# %% [markdown]
# ## Operações com Listas

# %%
lista1 =["phython","teste","QA","sql"]
lista2 = [1,2,3]

print(lista1 + lista2)
# Out:
# ['phython', 'teste', 'QA', 'sql', 1, 2, 3]

# %% [markdown]
# # Exercício 3
#
# # Queremos saber qual a média de idades dos alunos da turma
# # Vamos fazer esse cálculo por etapas
#
# # Calcule a soma dos elementos da lista
# # Digite seu código abaixo
#
#
#
# # Calcule a quantidade de itens na lista
# # Digite seu código abaixo
#
#
# # Agora calcule a média dividindo a soma pela quantidade de itens, chame o valor final de media
# # Digite seu código abaixo

# %%
idades = [30, 27, 31, 45, 50, 22, 18, 26, 30]

if idades == [30, 27, 31, 45, 50, 22, 18, 26, 30, 57]:
    print('Resposta Correta')
else:
    print('Tente Novamente')
# Out:
# Tente Novamente

# %%
somaidades = sum(idades)
print (somaidades)
# Out:
# 279

# %%
somaitens = len(idades)
print (somaitens)
# Out:
# 9

# %%
media = somaidades/somaitens
print (media)
# Out:
# 31.0

# %%
if media ==31:
    print('Resposta Correta')
else:
    print('Tente Novamente')
# Out:
# Resposta Correta

# %%
dict_idades = {'Pedro':30,'Carlos':27,'Maria':31,'Alice':45,'Marina':50,'Marcos':22,'Antonio':18,'José':26,'Renata':30}
maria = dict_idades["Maria"]
print("A idade de Maria é:",maria)
# Out:
# A idade de Maria é: 31

# %%
if maria ==31:
    print('Resposta Correta')
else:
    print('Tente Novamente')
# Out:
# Resposta Correta

# %% [markdown]
# # Temos um novo aluno na classe, o nome dele é Henrique e ele tem 50 anos. Atualize o dicionário:

# %%
dict_idades = {'Pedro':30,'Carlos':27,'Maria':31,'Alice':45,'Marina':50,'Marcos':22,'Antonio':18,'José':26,'Renata':30}

dict_atualizar = {"Henrique": 50}
dict_idades.update(dict_atualizar)
print( dict_idades)
# Out:
# {'Pedro': 30, 'Carlos': 27, 'Maria': 31, 'Alice': 45, 'Marina': 50, 'Marcos': 22, 'Antonio': 18, 'José': 26, 'Renata': 30, 'Henrique': 50}

# %%
if dict_idades['Henrique'] ==50:
    print('Resposta Correta')
else:
    print('Tente Novamente')
# Out:
# Resposta Correta

# %% [markdown]
# # Retorne a soma das idades de Pedro e Henrique e armazene o resultado na variável soma:

# %%
Pedro = dict_idades["Pedro"]
print(Pedro)
Henrique = dict_idades["Henrique"]
print(Henrique)
soma = Pedro+Henrique
print("A soma das idades, de Pedro e Henrique é igual á:",soma,"anos.")
# Out:
# 30
# 50
# A soma das idades, de Pedro e Henrique é igual á: 80 anos.

# %%
# Verificando a resposta:

if soma == 80:
    print('Resposta Correta')
else:
    print('Tente Novamente')
# Out:
# Resposta Correta
